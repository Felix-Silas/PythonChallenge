# %%
input()
# Out:
# 파이썬
# '파이썬'

# %%
input(3)
# Out:
# 3456
# '456'

# %%
input('입력 ')
# Out:
# 입력 7월 5일
# '7월 5일'

# %%
input('아이디: ')
input('비밀번호: ')
# Out:
# 아이디: gilbut
# 비밀번호: fighting!!!
# 'fighting!!!'

# %%
input('아이디: ')
input('비밀번호: ')
print('gilbut님 환영합니다!')
# Out:
# 아이디: gilbut
# 비밀번호: fighting!!!
# gilbut님 환영합니다!

# %%
print('---회원가입---')
input('아이디: ')
print('가입을 환영합니다! ')
# Out:
# ---회원가입---
# 아이디: gilbut
# 가입을 환영합니다!

# %%
print(input('아이디: ') + '님, 가입을 환영합니다!')
# Out:
# 아이디: gilbut
# gilbut님, 가입을 환영합니다!

# %%
print('---회원가입---')
print(input('아이디: ') + '님, 가입을 환영합니다!')
# Out:
# ---회원가입---
# 아이디: gilbut
# gilbut님, 가입을 환영합니다!

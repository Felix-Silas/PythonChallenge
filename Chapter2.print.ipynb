# %%
print(123)
print(2020)
print('가나다')
# Out:
# 123
# 2020
# 가나다

# %%
print(123 + 9)
print(123 - 9)
print('123 + 9')
print('123 - 9')
# Out:
# 132
# 114
# 123 + 9
# 123 - 9

# %%
print(108 * 8)
print(108 / 8)
# Out:
# 864
# 13.5

# %%
print(108 // 8)
print(108 % 8)
# Out:
# 13
# 4

# %%
print(108 ** 8)
print(5 ** 2)
# Out:
# 18509302102818816
# 25

# %%
print(14 + 31)
print('파이썬' + '프로그래밍')
print('파이썬', '프로그래밍')
print(14, 31)
# Out:
# 45
# 파이썬프로그래밍
# 파이썬 프로그래밍
# 14 31

# %%
print('파이썬' * 3)
# Out:
# 파이썬파이썬파이썬

# %%
print('파이썬+프로그래밍')
print('파이썬 + 프로그래밍')
# Out:
# 파이썬+프로그래밍
# 파이썬 + 프로그래밍

# %%
price = int(input('구매금액은? '))
marketing_yn = input('마케팅 이용약관에 동의했습니까? (Y/N) ')

if price >= 100000 and marketing_yn == 'Y':
    print('사은품 지급 대상입니다.')
else:
    print('사은품 지급 대상이 아닙니다.')
# Out:
# 구매금액은? 120000
# 마케팅 이용약관에 동의했습니까? (Y/N) Y
# 사은품 지급 대상입니다.

# %%
price = int(input('구매금액은? '))
marketing_yn = input('마케팅 이용약관에 동의했습니까? (Y/N) ')

if price >= 100000 or marketing_yn == 'Y':
    print('무료주차 대상입니다.')
else:
    print('무료주차 대상이 아닙니다.')
# Out:
# 구매금액은? 10200
# 마케팅 이용약관에 동의했습니까? (Y/N) Y
# 무료주차 대상입니다.
